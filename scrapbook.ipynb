# %%
import polars as pl
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import dates
from matplotlib.dates import DateFormatter
from datetime import datetime
from scipy.interpolate import CubicSpline
from scipy import interpolate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/overrides.py:7
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/_multiarray_umath.cpython-313-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/brian/Code/access/.pixi/envs/default/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/brian/Code/access/.pixi/envs/default/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.13 from "/Users/brian/Code/access/.pixi/envs/default/bin/python"
#   * The NumPy version is: "2.2.2"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/_multiarray_umath.cpython-313-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/brian/Code/access/.pixi/envs/default/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/brian/Code/access/.pixi/envs/default/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/brian/Code/access/.pixi/envs/default/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import polars as pl
# ----> 2 import matplotlib as mpl
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.ticker as ticker
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# File ~/Code/access/.pixi/envs/default/lib/python3.13/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_,
#     124     abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vecmat, void, vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.
